# %% [markdown]
# <a href="https://colab.research.google.com/github/menphes/rpa_challenge-robocorp/blob/main/RPA_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install selenium
# !apt update
# !apt install chromium-chromedriver

# %%
# =|=|=|=|=|=|=|=|=|= Start of Libs and Packs Import =|=|=|=|=|=|=|=|=|= #
import os, json, time, requests, urllib.request, re, os.path
import pandas as pd
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
# =|=|=|=|=|=|=|=|=|= End of Libs and Packs Import =|=|=|=|=|=|=|=|=|= #

# %%
# =|=|=|=|=|=|=|=|=|= Start of Function Definitions =|=|=|=|=|=|=|=|=|= #
class GoogleChrome:
    def __init__(self, urlPath, downloadPath=f"/content/sample_data"):
        """
        Initialize Browser Object.

        Args:
            urlPath (str): The Full URL to open the Browser to.
            downloadPath (str, optional): Path to Where Browser Downloads should be saved. Default is "Windows Standard Download"

        Returns:
            None
        """
        options = webdriver.ChromeOptions()
        options.add_argument('--window-size=1920,1080')
        options.add_argument('--headless')
        options.add_argument('--no-sandbox')
        options.add_argument('--disable-dev-shm-usage')
        prefs = {"download.default_directory": downloadPath, "directory_upgrade": True, "download.prompt_for_download": False, "plugins.always_open_pdf_externally": True}
        options.add_experimental_option("prefs", prefs)
        self.driver = webdriver.Chrome(options=options)
        self.driver.get(f"{urlPath}")
        self.action = ActionChains(self.driver)

    def get_current_url(self):
        """
        Get Active Tab Current URL.

        Args:
            None

        Returns:
            current_url (str): The URL for the currently active Chrome Tab
        """
        return self.driver.current_url

    def update_url(self, newURL):
        """
        Update Current Browser URL.

        Args:
            newURL (str): The Full URL to redirect the Browser to.

        Returns:
            None
        """
        self.driver.get(f"{newURL}")

    def take_screenshot(self, downloadPath=f"/content/sample_data"):
        """
        Update Current Browser URL.

        Args:
            downloadPath (str, optional): Path to Where Browser Downloads should be saved. Default is "Windows Standard Download"

        Returns:
            None
        """
        self.driver.get_screenshot_as_file(f'{downloadPath}/screenshot_{datetime.today()}.png')

    def get_element(self, elem, timeWait, searchType, waitType):
        """
        Find Specified Element.

        Args:
            elem (str): The Element's Full XPath, Class_Name or ID
            timeWait (int): Max time in Seconds to wait for Element
            searchType (str): The type of search to be used to find the Element. Options: 'xpath', 'id' or 'class'
            waitType (str): The type of waiting to be done. Options: 'visible', 'clickable', or 'present'

        Returns:
            element (obj): The object of the Element
        """
        if searchType == 'xpath':
            if str(elem)[:1] != '(' and str(elem)[-1:] != ')':
                elem = f"({str(elem).strip()})"
            searchType = By.XPATH
        elif searchType == 'id':
            searchType = By.ID
        elif searchType == 'class':
            elem = str(elem).strip().replace(' ', '.')
            searchType = By.CLASS_NAME
        if waitType == 'visible':
            waitType = EC.visibility_of_element_located
        elif waitType == 'clickable':
            waitType = EC.element_to_be_clickable
        elif waitType == 'present':
            waitType = EC.presence_of_element_located
        return WebDriverWait(self.driver, timeWait).until(waitType((searchType, elem)))

    def get_element_data(self, elem, timeWait, searchType='xpath', waitType='visible'):
        """
        Gets an Element's Properties Information.

        Args:
            elem (str): The Element's Full XPath, Class_Name or ID
            timeWait (int): Max time in Seconds to wait for Element
            searchType (str): The type of search to be used to find the Element. Default: 'xpath'. 'Options: 'xpath', 'id' or 'class'
            waitType (str): The type of waiting to be done. Default: 'visible'. Options: 'visible', 'clickable', or 'present'

        Returns:
            dictReturn (dict): Dictionary with Multiple Properties: ['Text', 'InnerText', 'Value', 'DValue', 'HRef', 'InnerHTML', 'AltText']
        """
        element = self.get_element(elem, timeWait, searchType, waitType)
        try:
            textVal = element.text
        except:
            textVal = ''
        try:
            valueVal = element.get_attribute('value')
        except:
            valueVal = ''
        try:
            dataVal = element.get_attribute('data-value')
        except:
            dataVal = ''
        try:
            hRefVal = element.get_attribute('href')
        except:
            hRefVal = ''
        try:
            innerTXTVal = element.get_attribute('innerText')
        except:
            innerTXTVal = ''
        try:
            innerHTMLVal = element.get_attribute("innerHTML")
        except:
            innerHTMLVal = ''
        try:
            altText = element.get_attribute("alt")
        except:
            altText = ''
        try:
            src = element.get_attribute('src')
        except:
            src = ""
        dictReturn = {'Text': textVal, 'InnerText':innerTXTVal, 'Value': valueVal, 'DValue':dataVal, 'HRef': hRefVal, 'InnerHTML': innerHTMLVal, 'AltText': altText, 'Source': src}
        return dictReturn

    def go_to_element(self, elem, timeWait, click=True, searchType='xpath', waitType='visible'):
        """
        Moves to an Element, while also being able to click it.

        Args:
            elem (str): The Element's Full XPath, Class_Name or ID
            timeWait (int): Max time in Seconds to wait for Element
            click (bool): Clicks the Element. Default: True
            searchType (str): The type of search to be used to find the Element. Default: 'xpath'. 'Options: 'xpath', 'id' or 'class'
            waitType (str): The type of waiting to be done. Default: 'visible'. Options: 'visible', 'clickable', or 'present'

        Returns:
            None
        """
        element = self.get_element(elem, timeWait, searchType, waitType)
        if click == True:
            try:
                self.action.move_to_element(element).click().perform()
            except:
                self.driver.execute_script("arguments[0].click();", element)
        else:
            self.action.move_to_element(element).perform()

    def loop_list(self, elem, timeWait, searchType='xpath', waitType='present'):
        """
        Loops through a HTML List and prints their respective items.

        Args:
            elem (str): The Element's Full XPath, Class_Name or ID
            timeWait (int): Max time in Seconds to wait for Element
            searchType (str): The type of search to be used to find the Element. Default: 'xpath'. 'Options: 'xpath', 'id' or 'class'
            waitType (str): The type of waiting to be done. Default: 'present'. Options: 'visible', 'clickable', or 'present'

        Returns:
            arrList (list): returns list of all List Item Texts
        """
        try:
            x = 0
            arrList = []
            while True:
                if x == 5:
                    print('ERROR: Unable to get Element! Please contact douglas.falcao@merckgroup.com')
                    return arrList
                listView = self.get_element(elem, timeWait, searchType, waitType)
                options = listView.find_elements(By.TAG_NAME, "li")
                if len(options) == 0:
                    x += 1
                    time.sleep(1)
                    continue
                for option in options:
                    arrList.append(option.text)
                return arrList
        except:
            print('ERROR: Issue with Website! Please contact douglas.falcao@merckgroup.com')
            return arrList

    def close(self):
        """
        Fully Closes the Test Chrome Browser and all of it's Tabs.

        Args:
            None

        Returns:
            None
        """
        self.driver.quit()
# =|=|=|=|=|=|=|=|=|= End of Function Definitions =|=|=|=|=|=|=|=|=|= #

# %%
param_search_phrase = input('Please insert search phrase: ').lower()
param_search_phrase = str(param_search_phrase).replace(' ','%20')
# Out:
# Please insert search phrase: us elections

# %%
param_categ_sect_topic = input('Please insert the news category/section/topic: ').lower()
# Out:
# Please insert the news category/section/topic: politics

# %%
param_qty_months = input('Please insert the number of months for which you need to receive news: ')
try:
  param_qty_months = int(param_qty_months)
except:
  print('Not a number.')
if param_qty_months <= 1:
  max_date = datetime.today().replace(day=1, hour=0, minute=0, second=0, microsecond=0)
else:
  max_date = datetime.today().replace(day=1, hour=0, minute=0, second=0, microsecond=0) - relativedelta(months=param_qty_months-1)
# Out:
# Please insert the number of months for which you need to receive news: 3

# %%
browser = GoogleChrome(f"https://www.latimes.com/search?q={param_search_phrase}&s=1")
browser.go_to_element(f"//div[@class='page-content']/ps-search-results-module/form/div[2]/ps-search-filters/div/aside/div/div[3]/div[1]/ps-toggler/ps-toggler/button", 15, waitType='clickable')
lst_topics = browser.loop_list(f"//div[@class='page-content']/ps-search-results-module/form/div[2]/ps-search-filters/div/aside/div/div[3]/div[1]/ps-toggler/ps-toggler/div/ul", 15)
lst_topics = [x.replace("\n", " ") for x in lst_topics]
lst_topics = [x.lower() for x in lst_topics]
lst_topics = [re.sub(r"\s[(][\d]*[)]", "", x) for x in lst_topics]
df_news = pd.DataFrame(columns =['title', 'description', 'date', 'img_description', 'img_location', 'money_mention'])
try:
  topics_checkbox_index = lst_topics.index(param_categ_sect_topic) + 1
  topic_filter_value = browser.get_element_data(f"//div[@class='page-content']/ps-search-results-module/form/div[2]/ps-search-filters/div/aside/div/div[3]/div[1]/ps-toggler/ps-toggler/div/ul/li[{topics_checkbox_index}]/div/div[1]/label/input", 15)['Value']
  browser.go_to_element(f"//div[@class='page-content']/ps-search-results-module/form/div[2]/ps-search-filters/div/aside/div/div[3]/div[1]/ps-toggler/ps-toggler/div/ul/li[{topics_checkbox_index}]/div/div[1]/label/input", 15, waitType='clickable')
  time.sleep(5)
except:
  print(f"No topic matching desired search: {param_categ_sect_topic}")
total_query_pages = int(str(browser.get_element_data(f"//div[@class='page-content']/ps-search-results-module/form/div[2]/ps-search-filters/div/main/div[2]/div[2]", 15)['Text']).split(' ')[2].replace(',', '')) + 1

for j in range(1, total_query_pages):
  for i in range(1, 11):
    news_title = browser.get_element_data(f"//div[@class='page-content']/ps-search-results-module/form/div[2]/ps-search-filters/div/main/ul/li[{i}]/ps-promo/div/div[2]/div/h3/a", 15)['Text']
    news_description = browser.get_element_data(f"//div[@class='page-content']/ps-search-results-module/form/div[2]/ps-search-filters/div/main/ul/li[{i}]/ps-promo/div/div[2]/p[1]", 15)['Text']
    try:
      news_date = browser.get_element_data(f"//div[@class='page-content']/ps-search-results-module/form/div[2]/ps-search-filters/div/main/ul/li[{i}]/ps-promo/div/div[2]/p[2]", 5)['Text']
      matches = re.findall(r"[$][\d]*[.,]?|[\d]*\sdollars|[\d]*\sUSD", news_description, re.MULTILINE)
      if not matches:
        money_mention = False
      else:
        money_mention = True
    except:
      news_date = news_description
      news_description = ""
      money_mention = False
    try:
      time_value = int(re.findall(r"[\d]+", news_date)[0])
    except:
      pass
    if 'second' in news_date.lower():
      news_date = datetime.today() - timedelta(seconds=time_value)
    elif 'minute' in news_date.lower():
      news_date = datetime.today() - timedelta(minutes=time_value)
    elif 'hour' in news_date.lower():
      news_date = datetime.today() - timedelta(hours=time_value)
    else:
      news_date = news_date
      try:
        news_date = datetime.strptime(news_date, '%b. %d, %Y')
      except:
        news_date = datetime.strptime(news_date, '%B %d, %Y')
    if max_date > news_date:
      break
    news_img_description = browser.get_element_data(f"//div[@class='page-content']/ps-search-results-module/form/div[2]/ps-search-filters/div/main/ul/li[{i}]/ps-promo/div/div[1]/a/picture/img", 15, searchType='xpath', waitType='visible')['AltText']
    try:
      news_img = browser.get_element(f"//div[@class='page-content']/ps-search-results-module/form/div[2]/ps-search-filters/div/main/ul/li[{i}]/ps-promo/div/div[1]/a/picture/img", 15, searchType='xpath', waitType='visible')
      src = news_img.get_attribute('src')
      urllib.request.urlretrieve(src, f'/content/sample_data/{param_search_phrase.replace("%20", "_")}-{j}_{i}.png')
      print(f'/content/sample_data/{param_search_phrase.replace("%20", "_")}-{j}_{i}.png')
      news_img_save_location = f'/content/sample_data/{param_search_phrase.replace("%20", "_")}-{j}_{i}.png'
      print(news_img_save_location)
    except:
      pass
    print(f'title: {news_title}')
    print(f'date: {news_date}\n')
    df_news = pd.concat([df_news, pd.DataFrame({'title': [news_title], 'description': [news_description], 'date': [news_date], 'img_description': [news_img_description], 'img_location': [news_img_save_location], 'money_mention': [money_mention]})], ignore_index=True)
  if max_date > news_date:
      break
  try:
    browser.go_to_element(f"/html/body/modality-custom-element//div/div/div/div/a", 10, waitType='clickable')
  except:
    pass
  curr_url = str(browser.get_current_url())
  if '+' in curr_url and '&p=' not in curr_url:
    base_url = curr_url
  curr_url = f"{str(base_url).replace('+', '%20')}&p={j+1}"
  browser.update_url(curr_url)
browser.close()
df_news.to_excel(f'/content/sample_data/{param_search_phrase.replace("%20", "_")}_{param_categ_sect_topic}_{param_qty_months}.xlsx', index=False)
df_news
# Out:
# /content/sample_data/us_elections-1_1.png
# /content/sample_data/us_elections-1_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
# <ipython-input-21-0ef58a52d335>:62: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_news = pd.concat([df_news, pd.DataFrame({'title': [news_title], 'description': [news_description], 'date': [news_date], 'img_description': [news_img_description], 'img_location': [news_img_save_location], 'money_mention': [money_mention]})], ignore_index=True)
# A saída de streaming foi truncada nas últimas 5000 linhas.
# /content/sample_data/us_elections-218_1.png
# /content/sample_data/us_elections-218_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
#
# /content/sample_data/us_elections-218_2.png
# /content/sample_data/us_elections-218_2.png
# title: The largely invisible presidential campaign on the ground in rural Michigan
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-218_3.png
# /content/sample_data/us_elections-218_3.png
# title: Hold the ‘blue wall,’ or light up the Sun Belt? Harris eyes path through U.S. battlegrounds
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-218_4.png
# /content/sample_data/us_elections-218_4.png
# title: Pro-Palestinian activists prepare to rally at Democratic convention in Chicago
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-218_5.png
# /content/sample_data/us_elections-218_5.png
# title: ‘I’ve never had an identity crisis’: Kamala Harris on the power of mixed-race California
# date: 2024-08-03 00:00:00
#
# /content/sample_data/us_elections-218_6.png
# /content/sample_data/us_elections-218_6.png
# title: Electoral politics become a subtext in dramatic prisoner swap with Russia
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-218_7.png
# /content/sample_data/us_elections-218_7.png
# title: DNC says Harris has a delegate majority. This is how its virtual roll call process works
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-218_8.png
# /content/sample_data/us_elections-218_8.png
# title: U.S. lawmakers join Latin American counterparts to form Panamerican Congress
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-218_9.png
# /content/sample_data/us_elections-218_9.png
# title: Tired of text spam from political fundraisers? Here’s what to do
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-218_10.png
# /content/sample_data/us_elections-218_10.png
# title: With $310 million, Harris raised more than twice as much as Trump in July
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-219_1.png
# /content/sample_data/us_elections-219_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
#
# /content/sample_data/us_elections-219_2.png
# /content/sample_data/us_elections-219_2.png
# title: The largely invisible presidential campaign on the ground in rural Michigan
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-219_3.png
# /content/sample_data/us_elections-219_3.png
# title: Hold the ‘blue wall,’ or light up the Sun Belt? Harris eyes path through U.S. battlegrounds
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-219_4.png
# /content/sample_data/us_elections-219_4.png
# title: Pro-Palestinian activists prepare to rally at Democratic convention in Chicago
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-219_5.png
# /content/sample_data/us_elections-219_5.png
# title: ‘I’ve never had an identity crisis’: Kamala Harris on the power of mixed-race California
# date: 2024-08-03 00:00:00
#
# /content/sample_data/us_elections-219_6.png
# /content/sample_data/us_elections-219_6.png
# title: Electoral politics become a subtext in dramatic prisoner swap with Russia
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-219_7.png
# /content/sample_data/us_elections-219_7.png
# title: DNC says Harris has a delegate majority. This is how its virtual roll call process works
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-219_8.png
# /content/sample_data/us_elections-219_8.png
# title: U.S. lawmakers join Latin American counterparts to form Panamerican Congress
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-219_9.png
# /content/sample_data/us_elections-219_9.png
# title: Tired of text spam from political fundraisers? Here’s what to do
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-219_10.png
# /content/sample_data/us_elections-219_10.png
# title: With $310 million, Harris raised more than twice as much as Trump in July
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-220_1.png
# /content/sample_data/us_elections-220_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
#
# /content/sample_data/us_elections-220_2.png
# /content/sample_data/us_elections-220_2.png
# title: The largely invisible presidential campaign on the ground in rural Michigan
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-220_3.png
# /content/sample_data/us_elections-220_3.png
# title: Hold the ‘blue wall,’ or light up the Sun Belt? Harris eyes path through U.S. battlegrounds
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-220_4.png
# /content/sample_data/us_elections-220_4.png
# title: Pro-Palestinian activists prepare to rally at Democratic convention in Chicago
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-220_5.png
# /content/sample_data/us_elections-220_5.png
# title: ‘I’ve never had an identity crisis’: Kamala Harris on the power of mixed-race California
# date: 2024-08-03 00:00:00
#
# /content/sample_data/us_elections-220_6.png
# /content/sample_data/us_elections-220_6.png
# title: Electoral politics become a subtext in dramatic prisoner swap with Russia
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-220_7.png
# /content/sample_data/us_elections-220_7.png
# title: DNC says Harris has a delegate majority. This is how its virtual roll call process works
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-220_8.png
# /content/sample_data/us_elections-220_8.png
# title: U.S. lawmakers join Latin American counterparts to form Panamerican Congress
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-220_9.png
# /content/sample_data/us_elections-220_9.png
# title: Tired of text spam from political fundraisers? Here’s what to do
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-220_10.png
# /content/sample_data/us_elections-220_10.png
# title: With $310 million, Harris raised more than twice as much as Trump in July
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-221_1.png
# /content/sample_data/us_elections-221_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
#
# /content/sample_data/us_elections-221_2.png
# /content/sample_data/us_elections-221_2.png
# title: The largely invisible presidential campaign on the ground in rural Michigan
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-221_3.png
# /content/sample_data/us_elections-221_3.png
# title: Hold the ‘blue wall,’ or light up the Sun Belt? Harris eyes path through U.S. battlegrounds
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-221_4.png
# /content/sample_data/us_elections-221_4.png
# title: Pro-Palestinian activists prepare to rally at Democratic convention in Chicago
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-221_5.png
# /content/sample_data/us_elections-221_5.png
# title: ‘I’ve never had an identity crisis’: Kamala Harris on the power of mixed-race California
# date: 2024-08-03 00:00:00
#
# /content/sample_data/us_elections-221_6.png
# /content/sample_data/us_elections-221_6.png
# title: Electoral politics become a subtext in dramatic prisoner swap with Russia
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-221_7.png
# /content/sample_data/us_elections-221_7.png
# title: DNC says Harris has a delegate majority. This is how its virtual roll call process works
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-221_8.png
# /content/sample_data/us_elections-221_8.png
# title: U.S. lawmakers join Latin American counterparts to form Panamerican Congress
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-221_9.png
# /content/sample_data/us_elections-221_9.png
# title: Tired of text spam from political fundraisers? Here’s what to do
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-221_10.png
# /content/sample_data/us_elections-221_10.png
# title: With $310 million, Harris raised more than twice as much as Trump in July
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-222_1.png
# /content/sample_data/us_elections-222_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
#
# /content/sample_data/us_elections-222_2.png
# /content/sample_data/us_elections-222_2.png
# title: The largely invisible presidential campaign on the ground in rural Michigan
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-222_3.png
# /content/sample_data/us_elections-222_3.png
# title: Hold the ‘blue wall,’ or light up the Sun Belt? Harris eyes path through U.S. battlegrounds
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-222_4.png
# /content/sample_data/us_elections-222_4.png
# title: Pro-Palestinian activists prepare to rally at Democratic convention in Chicago
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-222_5.png
# /content/sample_data/us_elections-222_5.png
# title: ‘I’ve never had an identity crisis’: Kamala Harris on the power of mixed-race California
# date: 2024-08-03 00:00:00
#
# /content/sample_data/us_elections-222_6.png
# /content/sample_data/us_elections-222_6.png
# title: Electoral politics become a subtext in dramatic prisoner swap with Russia
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-222_7.png
# /content/sample_data/us_elections-222_7.png
# title: DNC says Harris has a delegate majority. This is how its virtual roll call process works
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-222_8.png
# /content/sample_data/us_elections-222_8.png
# title: U.S. lawmakers join Latin American counterparts to form Panamerican Congress
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-222_9.png
# /content/sample_data/us_elections-222_9.png
# title: Tired of text spam from political fundraisers? Here’s what to do
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-222_10.png
# /content/sample_data/us_elections-222_10.png
# title: With $310 million, Harris raised more than twice as much as Trump in July
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-223_1.png
# /content/sample_data/us_elections-223_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
#
# /content/sample_data/us_elections-223_2.png
# /content/sample_data/us_elections-223_2.png
# title: The largely invisible presidential campaign on the ground in rural Michigan
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-223_3.png
# /content/sample_data/us_elections-223_3.png
# title: Hold the ‘blue wall,’ or light up the Sun Belt? Harris eyes path through U.S. battlegrounds
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-223_4.png
# /content/sample_data/us_elections-223_4.png
# title: Pro-Palestinian activists prepare to rally at Democratic convention in Chicago
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-223_5.png
# /content/sample_data/us_elections-223_5.png
# title: ‘I’ve never had an identity crisis’: Kamala Harris on the power of mixed-race California
# date: 2024-08-03 00:00:00
#
# /content/sample_data/us_elections-223_6.png
# /content/sample_data/us_elections-223_6.png
# title: Electoral politics become a subtext in dramatic prisoner swap with Russia
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-223_7.png
# /content/sample_data/us_elections-223_7.png
# title: DNC says Harris has a delegate majority. This is how its virtual roll call process works
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-223_8.png
# /content/sample_data/us_elections-223_8.png
# title: U.S. lawmakers join Latin American counterparts to form Panamerican Congress
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-223_9.png
# /content/sample_data/us_elections-223_9.png
# title: Tired of text spam from political fundraisers? Here’s what to do
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-223_10.png
# /content/sample_data/us_elections-223_10.png
# title: With $310 million, Harris raised more than twice as much as Trump in July
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-224_1.png
# /content/sample_data/us_elections-224_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
#
# /content/sample_data/us_elections-224_2.png
# /content/sample_data/us_elections-224_2.png
# title: The largely invisible presidential campaign on the ground in rural Michigan
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-224_3.png
# /content/sample_data/us_elections-224_3.png
# title: Hold the ‘blue wall,’ or light up the Sun Belt? Harris eyes path through U.S. battlegrounds
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-224_4.png
# /content/sample_data/us_elections-224_4.png
# title: Pro-Palestinian activists prepare to rally at Democratic convention in Chicago
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-224_5.png
# /content/sample_data/us_elections-224_5.png
# title: ‘I’ve never had an identity crisis’: Kamala Harris on the power of mixed-race California
# date: 2024-08-03 00:00:00
#
# /content/sample_data/us_elections-224_6.png
# /content/sample_data/us_elections-224_6.png
# title: Electoral politics become a subtext in dramatic prisoner swap with Russia
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-224_7.png
# /content/sample_data/us_elections-224_7.png
# title: DNC says Harris has a delegate majority. This is how its virtual roll call process works
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-224_8.png
# /content/sample_data/us_elections-224_8.png
# title: U.S. lawmakers join Latin American counterparts to form Panamerican Congress
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-224_9.png
# /content/sample_data/us_elections-224_9.png
# title: Tired of text spam from political fundraisers? Here’s what to do
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-224_10.png
# /content/sample_data/us_elections-224_10.png
# title: With $310 million, Harris raised more than twice as much as Trump in July
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-225_1.png
# /content/sample_data/us_elections-225_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
#
# /content/sample_data/us_elections-225_2.png
# /content/sample_data/us_elections-225_2.png
# title: The largely invisible presidential campaign on the ground in rural Michigan
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-225_3.png
# /content/sample_data/us_elections-225_3.png
# title: Hold the ‘blue wall,’ or light up the Sun Belt? Harris eyes path through U.S. battlegrounds
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-225_4.png
# /content/sample_data/us_elections-225_4.png
# title: Pro-Palestinian activists prepare to rally at Democratic convention in Chicago
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-225_5.png
# /content/sample_data/us_elections-225_5.png
# title: ‘I’ve never had an identity crisis’: Kamala Harris on the power of mixed-race California
# date: 2024-08-03 00:00:00
#
# /content/sample_data/us_elections-225_6.png
# /content/sample_data/us_elections-225_6.png
# title: Electoral politics become a subtext in dramatic prisoner swap with Russia
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-225_7.png
# /content/sample_data/us_elections-225_7.png
# title: DNC says Harris has a delegate majority. This is how its virtual roll call process works
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections
9.png
# title: Tired of text spam from political fundraisers? Here’s what to do
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-237_10.png
# /content/sample_data/us_elections-237_10.png
# title: With $310 million, Harris raised more than twice as much as Trump in July
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-238_1.png
# /content/sample_data/us_elections-238_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
#
# /content/sample_data/us_elections-238_2.png
# /content/sample_data/us_elections-238_2.png
# title: The largely invisible presidential campaign on the ground in rural Michigan
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-238_3.png
# /content/sample_data/us_elections-238_3.png
# title: Hold the ‘blue wall,’ or light up the Sun Belt? Harris eyes path through U.S. battlegrounds
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-238_4.png
# /content/sample_data/us_elections-238_4.png
# title: Pro-Palestinian activists prepare to rally at Democratic convention in Chicago
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-238_5.png
# /content/sample_data/us_elections-238_5.png
# title: ‘I’ve never had an identity crisis’: Kamala Harris on the power of mixed-race California
# date: 2024-08-03 00:00:00
#
# /content/sample_data/us_elections-238_6.png
# /content/sample_data/us_elections-238_6.png
# title: Electoral politics become a subtext in dramatic prisoner swap with Russia
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-238_7.png
# /content/sample_data/us_elections-238_7.png
# title: DNC says Harris has a delegate majority. This is how its virtual roll call process works
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-238_8.png
# /content/sample_data/us_elections-238_8.png
# title: U.S. lawmakers join Latin American counterparts to form Panamerican Congress
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-238_9.png
# /content/sample_data/us_elections-238_9.png
# title: Tired of text spam from political fundraisers? Here’s what to do
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-238_10.png
# /content/sample_data/us_elections-238_10.png
# title: With $310 million, Harris raised more than twice as much as Trump in July
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-239_1.png
# /content/sample_data/us_elections-239_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
#
# /content/sample_data/us_elections-239_2.png
# /content/sample_data/us_elections-239_2.png
# title: The largely invisible presidential campaign on the ground in rural Michigan
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-239_3.png
# /content/sample_data/us_elections-239_3.png
# title: Hold the ‘blue wall,’ or light up the Sun Belt? Harris eyes path through U.S. battlegrounds
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-239_4.png
# /content/sample_data/us_elections-239_4.png
# title: Pro-Palestinian activists prepare to rally at Democratic convention in Chicago
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-239_5.png
# /content/sample_data/us_elections-239_5.png
# title: ‘I’ve never had an identity crisis’: Kamala Harris on the power of mixed-race California
# date: 2024-08-03 00:00:00
#
# /content/sample_data/us_elections-239_6.png
# /content/sample_data/us_elections-239_6.png
# title: Electoral politics become a subtext in dramatic prisoner swap with Russia
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-239_7.png
# /content/sample_data/us_elections-239_7.png
# title: DNC says Harris has a delegate majority. This is how its virtual roll call process works
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-239_8.png
# /content/sample_data/us_elections-239_8.png
# title: U.S. lawmakers join Latin American counterparts to form Panamerican Congress
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-239_9.png
# /content/sample_data/us_elections-239_9.png
# title: Tired of text spam from political fundraisers? Here’s what to do
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-239_10.png
# /content/sample_data/us_elections-239_10.png
# title: With $310 million, Harris raised more than twice as much as Trump in July
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-240_1.png
# /content/sample_data/us_elections-240_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
#
# /content/sample_data/us_elections-240_2.png
# /content/sample_data/us_elections-240_2.png
# title: The largely invisible presidential campaign on the ground in rural Michigan
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-240_3.png
# /content/sample_data/us_elections-240_3.png
# title: Hold the ‘blue wall,’ or light up the Sun Belt? Harris eyes path through U.S. battlegrounds
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-240_4.png
# /content/sample_data/us_elections-240_4.png
# title: Pro-Palestinian activists prepare to rally at Democratic convention in Chicago
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-240_5.png
# /content/sample_data/us_elections-240_5.png
# title: ‘I’ve never had an identity crisis’: Kamala Harris on the power of mixed-race California
# date: 2024-08-03 00:00:00
#
# /content/sample_data/us_elections-240_6.png
# /content/sample_data/us_elections-240_6.png
# title: Electoral politics become a subtext in dramatic prisoner swap with Russia
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-240_7.png
# /content/sample_data/us_elections-240_7.png
# title: DNC says Harris has a delegate majority. This is how its virtual roll call process works
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-240_8.png
# /content/sample_data/us_elections-240_8.png
# title: U.S. lawmakers join Latin American counterparts to form Panamerican Congress
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-240_9.png
# /content/sample_data/us_elections-240_9.png
# title: Tired of text spam from political fundraisers? Here’s what to do
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-240_10.png
# /content/sample_data/us_elections-240_10.png
# title: With $310 million, Harris raised more than twice as much as Trump in July
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-241_1.png
# /content/sample_data/us_elections-241_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
#
# /content/sample_data/us_elections-241_2.png
# /content/sample_data/us_elections-241_2.png
# title: The largely invisible presidential campaign on the ground in rural Michigan
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-241_3.png
# /content/sample_data/us_elections-241_3.png
# title: Hold the ‘blue wall,’ or light up the Sun Belt? Harris eyes path through U.S. battlegrounds
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-241_4.png
# /content/sample_data/us_elections-241_4.png
# title: Pro-Palestinian activists prepare to rally at Democratic convention in Chicago
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-241_5.png
# /content/sample_data/us_elections-241_5.png
# ...
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-314_10.png
# /content/sample_data/us_elections-314_10.png
# title: With $310 million, Harris raised more than twice as much as Trump in July
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-315_1.png
# /content/sample_data/us_elections-315_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
#
# /content/sample_data/us_elections-315_2.png
# /content/sample_data/us_elections-315_2.png
# title: The largely invisible presidential campaign on the ground in rural Michigan
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-315_3.png
# /content/sample_data/us_elections-315_3.png
# title: Hold the ‘blue wall,’ or light up the Sun Belt? Harris eyes path through U.S. battlegrounds
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-315_4.png
# /content/sample_data/us_elections-315_4.png
# title: Pro-Palestinian activists prepare to rally at Democratic convention in Chicago
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-315_5.png
# /content/sample_data/us_elections-315_5.png
# title: ‘I’ve never had an identity crisis’: Kamala Harris on the power of mixed-race California
# date: 2024-08-03 00:00:00
#
# /content/sample_data/us_elections-315_6.png
# /content/sample_data/us_elections-315_6.png
# title: Electoral politics become a subtext in dramatic prisoner swap with Russia
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-315_7.png
# /content/sample_data/us_elections-315_7.png
# title: DNC says Harris has a delegate majority. This is how its virtual roll call process works
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-315_8.png
# /content/sample_data/us_elections-315_8.png
# title: U.S. lawmakers join Latin American counterparts to form Panamerican Congress
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-315_9.png
# /content/sample_data/us_elections-315_9.png
# title: Tired of text spam from political fundraisers? Here’s what to do
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-315_10.png
# /content/sample_data/us_elections-315_10.png
# title: With $310 million, Harris raised more than twice as much as Trump in July
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-316_1.png
# /content/sample_data/us_elections-316_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
#
# /content/sample_data/us_elections-316_2.png
# /content/sample_data/us_elections-316_2.png
# title: The largely invisible presidential campaign on the ground in rural Michigan
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-316_3.png
# /content/sample_data/us_elections-316_3.png
# title: Hold the ‘blue wall,’ or light up the Sun Belt? Harris eyes path through U.S. battlegrounds
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-316_4.png
# /content/sample_data/us_elections-316_4.png
# title: Pro-Palestinian activists prepare to rally at Democratic convention in Chicago
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-316_5.png
# /content/sample_data/us_elections-316_5.png
# title: ‘I’ve never had an identity crisis’: Kamala Harris on the power of mixed-race California
# date: 2024-08-03 00:00:00
#
# /content/sample_data/us_elections-316_6.png
# /content/sample_data/us_elections-316_6.png
# title: Electoral politics become a subtext in dramatic prisoner swap with Russia
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-316_7.png
# /content/sample_data/us_elections-316_7.png
# title: DNC says Harris has a delegate majority. This is how its virtual roll call process works
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-316_8.png
# /content/sample_data/us_elections-316_8.png
# title: U.S. lawmakers join Latin American counterparts to form Panamerican Congress
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-316_9.png
# /content/sample_data/us_elections-316_9.png
# title: Tired of text spam from political fundraisers? Here’s what to do
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-316_10.png
# /content/sample_data/us_elections-316_10.png
# title: With $310 million, Harris raised more than twice as much as Trump in July
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-317_1.png
# /content/sample_data/us_elections-317_1.png
# title: Robert F. Kennedy Jr. says he left a dead bear in Central Park as a prank
# date: 2024-08-05 00:00:00
#
# /content/sample_data/us_elections-317_2.png
# /content/sample_data/us_elections-317_2.png
# title: The largely invisible presidential campaign on the ground in rural Michigan
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-317_3.png
# /content/sample_data/us_elections-317_3.png
# title: Hold the ‘blue wall,’ or light up the Sun Belt? Harris eyes path through U.S. battlegrounds
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-317_4.png
# /content/sample_data/us_elections-317_4.png
# title: Pro-Palestinian activists prepare to rally at Democratic convention in Chicago
# date: 2024-08-04 00:00:00
#
# /content/sample_data/us_elections-317_5.png
# /content/sample_data/us_elections-317_5.png
# title: ‘I’ve never had an identity crisis’: Kamala Harris on the power of mixed-race California
# date: 2024-08-03 00:00:00
#
# /content/sample_data/us_elections-317_6.png
# /content/sample_data/us_elections-317_6.png
# title: Electoral politics become a subtext in dramatic prisoner swap with Russia
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-317_7.png
# /content/sample_data/us_elections-317_7.png
# title: DNC says Harris has a delegate majority. This is how its virtual roll call process works
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-317_8.png
# /content/sample_data/us_elections-317_8.png
# title: U.S. lawmakers join Latin American counterparts to form Panamerican Congress
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-317_9.png
# /content/sample_data/us_elections-317_9.png
# title: Tired of text spam from political fundraisers? Here’s what to do
# date: 2024-08-02 00:00:00
#
# /content/sample_data/us_elections-317_10.png
# /content/sample_data/us_elections-317_10.png
# title: With $310 million, Harris raised more than twice as much as Trump in July
# date: 2024-08-02 00:00:00
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectionResetError(104, 'Connection reset by peer')': /session/6290694dfb857a337d7bcd731b2f1f5e/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x79ad6437aad0>: Failed to establish a new connection: [Errno 111] Connection refused')': /session/6290694dfb857a337d7bcd731b2f1f5e/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x79ad643e7370>: Failed to establish a new connection: [Errno 111] Connection refused')': /session/6290694dfb857a337d7bcd731b2f1f5e/url
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in _new_conn(self)
#     202         try:
# --> 203             sock = connection.create_connection(
#     204                 (self._dns_host, self.port),
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84         try:
# ---> 85             raise err
#      86         finally:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     496         try:
# --> 497             conn.request(
#     498                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     394             self.putheader(header, value)
# --> 395         self.endheaders()
#     396
#
# /usr/lib/python3.10/http/client.py in endheaders(self, message_body, encode_chunked)
#    1277             raise CannotSendHeader()
# -> 1278         self._send_output(message_body, encode_chunked=encode_chunked)
#    1279
#
# /usr/lib/python3.10/http/client.py in _send_output(self, message_body, encode_chunked)
#    1037         del self._buffer[:]
# -> 1038         self.send(msg)
#    1039
#
# /usr/lib/python3.10/http/client.py in send(self, data)
#     975             if self.auto_open:
# --> 976                 self.connect()
#     977             else:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in connect(self)
#     242     def connect(self) -> None:
# --> 243         self.sock = self._new_conn()
#     244         if self._tunnel_host:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in _new_conn(self)
#     217         except OSError as e:
# --> 218             raise NewConnectionError(
#     219                 self, f"Failed to establish a new connection: {e}"
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x79ad643e7520>: Failed to establish a new connection: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-21-0ef58a52d335> in <cell line: 17>()
#      67   except:
#      68     pass
# ---> 69   curr_url = str(browser.get_current_url())
#      70   if '+' in curr_url and '&p=' not in curr_url:
#      71     base_url = curr_url
#
# <ipython-input-3-b262174ce394> in get_current_url(self)
#      36             current_url (str): The URL for the currently active Chrome Tab
#      37         """
# ---> 38         return self.driver.current_url
#      39
#      40     def update_url(self, newURL):
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in current_url(self)
#     442                 driver.current_url
#     443         """
# --> 444         return self.execute(Command.GET_CURRENT_URL)["value"]
#     445
#     446     @property
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     350                 params["sessionId"] = self.session_id
#     351
# --> 352         response = self.command_executor.execute(driver_command, params)
#     353         if response:
#     354             self.error_handler.check_response(response)
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     300         trimmed = self._trim_large_entries(params)
#     301         LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 302         return self._request(command_info[0], url, body=data)
#     303
#     304     def _request(self, method, url, body=None):
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     320
#     321         if self.keep_alive:
# --> 322             response = self._conn.request(method, url, body=body, headers=headers)
#     323             statuscode = response.status
#     324         else:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/_request_methods.py in request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     108
#     109         if method in self._encode_url_methods:
# --> 110             return self.request_encode_url(
#     111                 method,
#     112                 url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/_request_methods.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#     141             url += "?" + urlencode(fields)
#     142
# --> 143         return self.urlopen(method, url, **extra_kw)
#     144
#     145     def request_encode_body(
#
# /usr/local/lib/python3.10/dist-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     441             response = conn.urlopen(method, url, **kw)
#     442         else:
# --> 443             response = conn.urlopen(method, u.request_uri, **kw)
#     444
#     445         redirect_location = redirect and response.get_redirect_location()
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     873                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     874             )
# --> 875             return self.urlopen(
#     876                 method,
#     877                 url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     873                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     874             )
# --> 875             return self.urlopen(
#     876                 method,
#     877                 url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     873                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     874             )
# --> 875             return self.urlopen(
#     876                 method,
#     877                 url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     843                 new_e = ProtocolError("Connection aborted.", new_e)
#     844
# --> 845             retries = retries.increment(
#     846                 method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     847             )
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     513         if new_retry.is_exhausted():
#     514             reason = error or ResponseError(cause)
# --> 515             raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     516
#     517         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=34901): Max retries exceeded with url: /session/6290694dfb857a337d7bcd731b2f1f5e/url (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x79ad643e7520>: Failed to establish a new connection: [Errno 111] Connection refused'))
